# %% [markdown]
# # LaTeX Learning

# %% [markdown]
# The Jupyter Notebook uses MathJax to render LaTeX inside HTML / Markdown.
#
# Just put your LaTeX math inside single dollars, or enter in display math mode by writing between double dollars

# %% [markdown]
# To insert a Mathematical function, we use a dollar symbol $, as follows

# %% [markdown]
# Euler's identity : $ e^{i \pi} + 1 = 0 $

# %% [markdown]
# To isolate and center the formulas and enter in math display mode, we use 2 dollars symbol:

# %% [markdown]
# $$
# ...........................................:::::::::::::::::::........::::::::::::::::::..........................................
# $$

# %% [markdown]
# $$
# ...........................................:::::::::::::::::::........::::::::::::::::::..........................................
# $$

# %% [markdown]
# Euler's identity : $$ e^{i \pi} + 1 = 0$$

# %% [markdown]
# Euler's identity : $$ e^{i \pi} + 1 = 0$$

# %% [markdown]
# Important Notes:
#
# 1. To add little spacing in math mode use \,
# 2. To add a new line in math mode use \\
# 3. To display fraction use \frac{arg1}(arg2)
# 4. For power (superscript text) use ^{}
# 5. For indices (subscript text) use _{}
# 6. For roots use \sqrt[n]{arg}

# %% [markdown]
# $$
# \frac{arg 1}{arg 2} \\
# x^2\\
# e^{i\pi}\\
# A_i\\
# B_{ij}\\
# \sqrt[n]{arg}
# $$

# %% [markdown]
# $$
# \frac{arg 1}{arg 2} \\
# x^2\\
# e^{i\pi}\\
# A_i\\
# B_{ij}\\
# \sqrt[n]{arg}
# $$

# %% [markdown]
# $$\sqrt[2]{4} = 2$$

# %% [markdown]
# ## Greek Letters

# %% [markdown]
# ![1*rvn-mNdprK7m1koOns8ilg.png](attachment:1*rvn-mNdprK7m1koOns8ilg.png)

# %% [markdown]
# Given : $\pi = 3.14$ , $\alpha = \frac{3\pi}{4}\, rad$
# $$
# \omega = 2\pi f \\
# f = \frac{c}{\lambda}\\
# \lambda_0=\theta^2+\delta\\
# \Delta\lambda = \frac{1}{\lambda^2}
# $$

# %% [markdown]
# #### Practice

# %% [markdown]
# Given : $\pi = 3.14$ , $\alpha = \frac{3\pi}{4} \, rad$
# $$
# \omega = 2\pi f\\
# f = \frac{c}{\lambda}\\
# \lambda_0 = \theta^2 + \delta\\
# \Delta \lambda = \frac{1}{\lambda^2}
# $$

# %% [markdown]
# To write Capital Greek Letter, type the first case after the backslash \as an uppercase
#
# for example:

# %% [markdown]
# $$
# \delta\\
# \Delta\\
# \omega\\
# \Omega
# $$

# %% [markdown]
# ## Roman Names

# %% [markdown]
# $$
# \sin(-\alpha)=-\sin(\alpha)\\
# \arccos(x)=\arcsin(u)\\
# \log_n(n)=1\\
# \tan(x) = \frac{\sin(x)}{\cos(x)}
# $$

# %% [markdown]
# ![1*7dib0gZYUE3_2Ac3CClazw.png](attachment:1*7dib0gZYUE3_2Ac3CClazw.png)

# %% [markdown]
# ## Other Symbols

# %% [markdown]
# ### Angles:
# Left angle : $\langle$
#
# Right angle : $\rangle$
#
# Angle between two vectors u and v	: $\langle \vec{u},\vec{v}\rangle$
#
# $$ \vec{AB} \, \cdot \, \vec{CD} =0  \Rightarrow  \vec{AB} \, \perp\, \vec{CD}$$

# %% [markdown]
# ### Angles:
# Left angle : $\langle$
#
# Right angle : $\rangle$
#
# Angle between two vectors u and v	: $\langle \vec{u},\vec{v}\rangle$
#
# $$ \vec{AB} \, \cdot \, \vec{CD} =0  \Rightarrow  \vec{AB} \, \perp\, \vec{CD}$$

# %% [markdown]
# ### Sets and logic
# $$\mathbb{N} \subset \mathbb{Z} \subset \mathbb{D} \subset \mathbb{Q} \subset \mathbb{R} \subset \mathbb{C}$$

# %% [markdown]
# ![1*8qpYLNPmlvEoEMaoksfINA.png](attachment:1*8qpYLNPmlvEoEMaoksfINA.png)

# %% [markdown]
# ![1*IgyFkP0Z9Dk6QQumL5sClQ.png](attachment:1*IgyFkP0Z9Dk6QQumL5sClQ.png)

# %% [markdown]
# ![1*ODvw1B-e_Kpgl4iQ93O86A.png](attachment:1*ODvw1B-e_Kpgl4iQ93O86A.png)

# %% [markdown]
# ### Vertical Curly Braces

# %% [markdown]
# $$
# sign(x) = \left\{
#     \begin{array}\\
#         1 & \mbox{if } \ x \in \mathbf{N}^* \\
#         0 & \mbox{if } \ x = 0 \\
#         -1 & \mbox{else.}
#     \end{array}
# \right.
# $$
#
# \\
#
# $$
#  \left.
#     \begin{array} \\
#         \alpha^2 = \sqrt5 \\
#         \alpha \geq 0
#     \end{array}
# \right \}=\alpha = 5
# $$

# %% [markdown]
# $$
# sign(x) = \left\{
#     \begin{array}\\
#         1 & \mbox{if } \ x \in \mathbf{N}^* \\
#         0 & \mbox{if } \ x = 0 \\
#         -1 & \mbox{else.}
#     \end{array}
# \right.
# $$
#
# \\
#
# $$
#  \left.
#     \begin{array} \\
#         \alpha^2 = \sqrt5 \\
#         \alpha \geq 0
#     \end{array}
# \right \}=\alpha = 5
# $$

# %% [markdown]
# ### Horizontal Curly Braces

# %% [markdown]
# $$
# \underbrace{\ln \left( \frac{5}{6} \right)}_{\simeq -0.1823}
# < \overbrace{\exp (2)}^{\simeq 7.3890}
# $$

# %% [markdown]
# $$
# \underbrace{\ln \left( \frac{5}{6} \right)}_{\simeq -0.1823}
# < \overbrace{\exp (2)}^{\simeq 7.3890}
# $$

# %% [markdown]
# ### Derivative

# %% [markdown]
# First order derivative : $$f'(x)$$
# K-th order derivative  : $$f^{(k)}(x)$$
# Partial firt order deivative	: $$\frac{\partial f}{\partial x}$$
# Partial k-th order derivative	: $$\frac{\partial^{k} f}{\partial x^k}$$

# %% [markdown]
# First order derivative : $$f'(x)$$
# K-th order derivative  : $$f^{(k)}(x)$$
# Partial firt order deivative	: $$\frac{\partial f}{\partial x}$$
# Partial k-th order derivative	: $$\frac{\partial^{k} f}{\partial x^k}$$

# %% [markdown]
# ### Limits

# %% [markdown]
# #limit
# Limit at plus infinity	: $$\lim_{x \to +\infty} f(x)$$
# Limit at minus infinity	: $$\lim_{x \to -\infty} f(x)$$
# Limit at $\alpha$  : $$\lim_{x \to \alpha} f(x)$$
#
# Max : $$\max_{x \in [a,b]}f(x)$$
# Min : $$\min_{x \in [\alpha,\beta]}f(x)$$
# Sup : $$\sup_{x \in \mathbb{R}}f(x)$$
# Inf : $$\inf_{x > s}f(x)$$

# %% [markdown]
# #limit
# Limit at plus infinity	: $$\lim_{x \to +\infty} f(x)$$
# Limit at minus infinity	: $$\lim_{x \to -\infty} f(x)$$
# Limit at $\alpha$  : $$\lim_{x \to \alpha} f(x)$$
#
# Max : $$\max_{x \in [a,b]}f(x)$$
# Min : $$\min_{x \in [\alpha,\beta]}f(x)$$
# Sup : $$\sup_{x \in \mathbb{R}}f(x)$$
# Inf : $$\inf_{x > s}f(x)$$

# %% [markdown]
# ### Sum

# %% [markdown]
# Sum from 0 to +inf:
#
# $$\sum_{j=0}^{+\infty} A_{j}$$
#
# Double sum:
# $$\sum^k_{i=1}\sum^{l+1}_{j=1}\,A_i A_j$$
#
#
# Taylor expansion of $e^x$:
# $$ e^x  = \sum_{k=0}^{n}\, \frac{x^k}{k!} + o(x^n) $$

# %% [markdown]
# Sum from 0 to +inf:
#
# $$\sum_{j=0}^{+\infty} A_{j}$$
#
# Double sum:
# $$\sum^k_{i=1}\sum^{l+1}_{j=1}\,A_i A_j$$
#
#
# Taylor expansion of $e^x$:
# $$ e^x  = \sum_{k=0}^{n}\, \frac{x^k}{k!} + o(x^n) $$

# %% [markdown]
# ### Product

# %% [markdown]
# Product:
# $$\prod_{j=1}^k A_{\alpha_j}$$
# Double product:
# $$\prod^k_{i=1}\prod^l_{j=1}\,A_i A_j$$

# %% [markdown]
# Product:
# $$\prod_{j=1}^k A_{\alpha_j}$$
# Double product:
# $$\prod^k_{i=1}\prod^l_{j=1}\,A_i A_j$$

# %% [markdown]
# ### Integral

# %% [markdown]
# Simple integral:
# $$\int_{a}^b f(x)dx$$
#
# Double integral:
# $$\int_{a}^b\int_{c}^d f(x,y)\,dxdy$$
#
# Triple integral:
# $$\iiint$$
#
# Quadruple integral:
# $$\iiiint$$
#
# Multiple integral :
# $$\idotsint$$
#
# Contour integral:
# $$\oint$$

# %% [markdown]
# Simple integral:
# $$\int_{a}^b f(x)dx$$
#
# Double integral:
# $$\int_{a}^b\int_{c}^d f(x,y)\,dxdy$$
#
# Triple integral:
# $$\iiint$$
#
# Quadruple integral:
# $$\iiiint$$
#
# Multiple integral :
# $$\idotsint$$
#
# Contour integral:
# $$\oint$$

# %% [markdown]
# ### Matrix

# %% [markdown]
# Plain:
#
# \begin{matrix}
# 1 & 2 & 3\\
# a & b & c
# \end{matrix}
#
# Round brackets:
# \begin{pmatrix}
# 1 & 2 & 3\\
# a & b & c
# \end{pmatrix}
#
# Curly brackets:
# \begin{Bmatrix}
# 1 & 2 & 3\\
# a & b & c
# \end{Bmatrix}
#
# Pipes:
# \begin{vmatrix}
# 1 & 2 & 3\\
# a & b & c
# \end{vmatrix}
#
# Double pipes
# \begin{Vmatrix}
# 1 & 2 & 3\\
# a & b & c
# \end{Vmatrix}
# view raw

# %% [markdown]
# Plain:
#
# \begin{matrix}
# 1 & 2 & 3\\
# a & b & c
# \end{matrix}
#
# Round brackets:
# \begin{pmatrix}
# 1 & 2 & 3\\
# a & b & c
# \end{pmatrix}
#
# Curly brackets:
# \begin{Bmatrix}
# 1 & 2 & 3\\
# a & b & c
# \end{Bmatrix}
#
# Pipes:
# \begin{vmatrix}
# 1 & 2 & 3\\
# a & b & c
# \end{vmatrix}
#
# Double pipes
# \begin{Vmatrix}
# 1 & 2 & 3\\
# a & b & c
# \end{Vmatrix}
# view raw
